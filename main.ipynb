# %%
# First download the data.
# Here is the link to the data
# https://www.sgdml.org/#datasets

# %%
import sys
import os

# 1. Get the current path and add 'src' to it
# This tells Python: "Look inside the src folder for modules too"
sys.path.append(os.path.abspath("src"))

# %%
# Benzene

# Trains the model
import src.train_benzene

# Makes the simulation
import simulation_robust_benzene
# Out:
# Python: /home/lyngsberg/miniconda3/envs/deepLearning/bin/python
# Torch CUDA: 12.8
# torch-cluster: /home/lyngsberg/miniconda3/envs/deepLearning/lib/python3.12/site-packages/torch_cluster/__init__.py
# torch-cluster version: 1.6.3
# Using device: cuda
# wandb: Currently logged in as: lyngsberg to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.23.0
# Run data is saved locally in <code>/home/lyngsberg/deepLearning/02456-MD-with-GNNs/wandb/run-20251205_120749-eajwral5</code>
# Syncing run <strong><a href='https://wandb.ai/lyngsberg-danmarks-tekniske-universitet-dtu/DeepLearningProject/runs/eajwral5' target="_blank">painn-benzene2018_dft</a></strong> to <a href='https://wandb.ai/lyngsberg-danmarks-tekniske-universitet-dtu/DeepLearningProject' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/lyngsberg-danmarks-tekniske-universitet-dtu/DeepLearningProject' target="_blank">https://wandb.ai/lyngsberg-danmarks-tekniske-universitet-dtu/DeepLearningProject</a>
#  View run at <a href='https://wandb.ai/lyngsberg-danmarks-tekniske-universitet-dtu/DeepLearningProject/runs/eajwral5' target="_blank">https://wandb.ai/lyngsberg-danmarks-tekniske-universitet-dtu/DeepLearningProject/runs/eajwral5</a>
# /home/lyngsberg/miniconda3/envs/deepLearning/lib/python3.12/site-packages/torch/cuda/__init__.py:283: UserWarning:
#     Found GPU0 NVIDIA GeForce GTX 1050 Ti with Max-Q Design which is of cuda capability 6.1.
#     Minimum and Maximum cuda capability supported by this version of PyTorch is
#     (7.0) - (12.0)
#
#   warnings.warn(
# /home/lyngsberg/miniconda3/envs/deepLearning/lib/python3.12/site-packages/torch/cuda/__init__.py:304: UserWarning:
#     Please install PyTorch with a following CUDA
#     configurations:  12.6 following instructions at
#     https://pytorch.org/get-started/locally/
#
#   warnings.warn(matched_cuda_warn.format(matched_arches))
# /home/lyngsberg/miniconda3/envs/deepLearning/lib/python3.12/site-packages/torch/cuda/__init__.py:326: UserWarning:
# NVIDIA GeForce GTX 1050 Ti with Max-Q Design with CUDA capability sm_61 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_70 sm_75 sm_80 sm_86 sm_90 sm_100 sm_120.
# If you want to use the NVIDIA GeForce GTX 1050 Ti with Max-Q Design GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Ethanol

# Trains the model
import src.train_ethanol

# Makes the simulation
import simulation_robust_ethanol

# %%
# Paracetamol

# Trains the model
import src.train_paracetamol

# Makes the simulation
import simulation_robust_paracetamol

# %%
# Benzene bayesion

# Trains the model
import src.train_baysian

# Makes the simulation
import simulation_robust_bayesian
